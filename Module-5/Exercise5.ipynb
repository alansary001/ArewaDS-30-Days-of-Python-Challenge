# %% [markdown]
# ## module 5 (List)

# %% [markdown]
# ### exercise 1

# %%
empty_list = []
items_list  = [1, 2, 3, 4, 5, 6]
print(len(items_list))

# Get the first item, the middle item, and the last item of the list
first_item = items_list[0]
middle_item = items_list[len(items_list) // 2]
last_item = items_list[-1]
print(f"First: {first_item}, Middle: {middle_item}, Last: {last_item}")

# Declare a list called mixed_data_types
mixed_data_types = ["Ahmad Mustapha", 30, 5.9, "Married", "Kano, Nigeria"]

# Declare a list variable named it_companies
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle", "Amazon"]

# Print the list
print(it_companies)

# Print the number of companies in the list
print(len(it_companies))  # Output: 7

# Print the first, middle, and last company
print(f"First: {it_companies[0]}, Middle: {it_companies[len(it_companies) // 2]}, Last: {it_companies[-1]}")

# Modify one of the companies
it_companies[0] = "Meta"
print(it_companies)

# Add an IT company to the list
it_companies.append("Twitter")
print(it_companies)

# Insert an IT company in the middle
it_companies.insert(len(it_companies) // 2, "Tesla")
print(it_companies)

# Change one of the IT company names to uppercase (excluding IBM)
it_companies[1] = it_companies[1].upper()  # Change Google to GOOGLE
print(it_companies)

# Join the it_companies with a string '#; '
joined_companies = "#; ".join(it_companies)
print(joined_companies)

# Check if a certain company exists in the list
company_exists = "Apple" in it_companies
print(f"Is Apple in the list? {company_exists}")

# Sort the list
it_companies.sort()
print(it_companies)

# Reverse the list in descending order
it_companies.reverse()
print(it_companies)

# Slice out the first 3 companies from the list
first_three = it_companies[:3]
print(first_three)

# Slice out the last 3 companies from the list
last_three = it_companies[-3:]
print(last_three)

# Slice out the middle IT company or companies
middle_index = len(it_companies) // 2
if len(it_companies) % 2 == 0:
    middle_companies = it_companies[middle_index - 1:middle_index + 1]
else:
    middle_companies = it_companies[middle_index]
print(middle_companies)

# Remove the first IT company from the list
it_companies.pop(0)
print(it_companies)

# Remove the middle IT company or companies
middle_index = len(it_companies) // 2
it_companies.pop(middle_index)
print(it_companies)

# Remove the last IT company from the list
it_companies.pop(-1)
print(it_companies)

# Remove all IT companies from the list
it_companies.clear()
print(it_companies)

# Destroy the IT companies list
del it_companies

# Join the following lists
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node', 'Express', 'MongoDB']
joined_list = front_end + back_end
print(joined_list)

# Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux
full_stack = joined_list.copy()
redux_index = full_stack.index('Redux')
full_stack.insert(redux_index + 1, 'Python')
full_stack.insert(redux_index + 2, 'SQL')
print(full_stack)
# Out:
# 6
# First: 1, Middle: 4, Last: 6
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# 7
# First: Facebook, Middle: Apple, Last: Amazon
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# ['Meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Twitter']
# ['Meta', 'Google', 'Microsoft', 'Apple', 'Tesla', 'IBM', 'Oracle', 'Amazon', 'Twitter']
# ['Meta', 'GOOGLE', 'Microsoft', 'Apple', 'Tesla', 'IBM', 'Oracle', 'Amazon', 'Twitter']
# Meta#; GOOGLE#; Microsoft#; Apple#; Tesla#; IBM#; Oracle#; Amazon#; Twitter
# Is Apple in the list? True
# ['Amazon', 'Apple', 'GOOGLE', 'IBM', 'Meta', 'Microsoft', 'Oracle', 'Tesla', 'Twitter']
# ['Twitter', 'Tesla', 'Oracle', 'Microsoft', 'Meta', 'IBM', 'GOOGLE', 'Apple', 'Amazon']
# ['Twitter', 'Tesla', 'Oracle']
# ['GOOGLE', 'Apple', 'Amazon']
# Meta
# ['Tesla', 'Oracle', 'Microsoft', 'Meta', 'IBM', 'GOOGLE', 'Apple', 'Amazon']
# ...

# %% [markdown]
# ### exercise 2

# %%
# List of ages
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

# Sort the list and find the min and max age
ages.sort()
min_age = min(ages)
max_age = max(ages)
print(f"Sorted ages: {ages}")
print(f"Min age: {min_age}, Max age: {max_age}")

# Add the min age and the max age again to the list
ages.append(min_age)
ages.append(max_age)
print(f"Updated ages: {ages}")

# Find the median age
ages.sort()  # Sort again to ensure the list is ordered
n = len(ages)
if n % 2 == 0:
    median_age = (ages[n // 2 - 1] + ages[n // 2]) / 2
else:
    median_age = ages[n // 2]
print(f"Median age: {median_age}")

# Find the average age
average_age = sum(ages) / len(ages)
print(f"Average age: {average_age}")

# Find the range of the ages
age_range = max_age - min_age
print(f"Age range: {age_range}")

# Compare (min - average) and (max - average) using abs()
min_diff = abs(min_age - average_age)
max_diff = abs(max_age - average_age)
print(f"Min - Average: {min_diff}, Max - Average: {max_diff}")

# List of countries
countries = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']

# Find the middle country(ies)
n_countries = len(countries)
if n_countries % 2 == 0:
    middle_countries = countries[n_countries // 2 - 1:n_countries // 2 + 1]
else:
    middle_countries = [countries[n_countries // 2]]
print(f"Middle country(ies): {middle_countries}")

# Divide the countries list into two equal lists
half = n_countries // 2
if n_countries % 2 == 0:
    first_half = countries[:half]
    second_half = countries[half:]
else:
    first_half = countries[:half + 1]
    second_half = countries[half + 1:]
print(f"First half: {first_half}")
print(f"Second half: {second_half}")

# Unpack the first three countries and the rest as scandic countries
first, second, third, *scandic_countries = countries
print(f"First three countries: {first}, {second}, {third}")
print(f"Scandic countries: {scandic_countries}")
# Out:
# Sorted ages: [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]
# Min age: 19, Max age: 26
# Updated ages: [19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 19, 26]
# Median age: 24.0
# Average age: 22.75
# Age range: 7
# Min - Average: 3.75, Max - Average: 3.25
# Middle country(ies): ['Finland']
# First half: ['China', 'Russia', 'USA', 'Finland']
# Second half: ['Sweden', 'Norway', 'Denmark']
# First three countries: China, Russia, USA
# Scandic countries: ['Finland', 'Sweden', 'Norway', 'Denmark']

# %% [markdown]
# ### exercise 3 tuples

# %%
# Level 1 Exercises

# Create an empty tuple
empty_tuple = ()
print(f"Empty tuple: {empty_tuple}")

# Create a tuple containing names of your sisters and your brothers
sisters = ("Aisha", "Zainab", "Fatima")
brothers = ("Nasiru", "Mustapha", "Yusuf")

# Join brothers and sisters tuples and assign it to siblings
siblings = sisters + brothers
print(f"Siblings: {siblings}")

# How many siblings do you have?
number_of_siblings = len(siblings)
print(f"Number of siblings: {number_of_siblings}")

# Modify the siblings tuple and add the name of your father and mother
family_members = siblings + ("Father", "Mother")
print(f"Family members: {family_members}")

# Level 2 Exercises

# Unpack siblings and parents from family_members
*siblings_unpack, father, mother = family_members
print(f"Siblings: {siblings_unpack}, Father: {father}, Mother: {mother}")

# Create fruits, vegetables, and animal products tuples
fruits = ("Apple", "Banana", "Mango")
vegetables = ("Carrot", "Tomato", "Spinach")
animal_products = ("Milk", "Cheese", "Eggs")

# Join the three tuples and assign it to food_stuff_tp
food_stuff_tp = fruits + vegetables + animal_products
print(f"Food stuff (tuple): {food_stuff_tp}")

# Change food_stuff_tp tuple to a food_stuff_lt list
food_stuff_lt = list(food_stuff_tp)
print(f"Food stuff (list): {food_stuff_lt}")

# Slice out the middle item or items from the food_stuff_tp tuple or food_stuff_lt list
n = len(food_stuff_lt)
if n % 2 == 0:
    middle_items = food_stuff_lt[n // 2 - 1:n // 2 + 1]
else:
    middle_items = [food_stuff_lt[n // 2]]
print(f"Middle item(s): {middle_items}")

# Slice out the first three items and the last three items from the food_stuff_lt list
first_three = food_stuff_lt[:3]
last_three = food_stuff_lt[-3:]
print(f"First three items: {first_three}")
print(f"Last three items: {last_three}")

# Delete the food_stuff_tp tuple completely
del food_stuff_tp

# Check if an item exists in a tuple
nordic_countries = ('Denmark', 'Finland', 'Iceland', 'Norway', 'Sweden')

# Check if 'Estonia' is a nordic country
is_estonia_nordic = "Estonia" in nordic_countries
print(f"Is Estonia a nordic country? {is_estonia_nordic}")

# Check if 'Iceland' is a nordic country
is_iceland_nordic = "Iceland" in nordic_countries
print(f"Is Iceland a nordic country? {is_iceland_nordic}")
# Out:
# Empty tuple: ()
# Siblings: ('Aisha', 'Zainab', 'Fatima', 'Nasiru', 'Mustapha', 'Yusuf')
# Number of siblings: 6
# Family members: ('Aisha', 'Zainab', 'Fatima', 'Nasiru', 'Mustapha', 'Yusuf', 'Father', 'Mother')
# Siblings: ['Aisha', 'Zainab', 'Fatima', 'Nasiru', 'Mustapha', 'Yusuf'], Father: Father, Mother: Mother
# Food stuff (tuple): ('Apple', 'Banana', 'Mango', 'Carrot', 'Tomato', 'Spinach', 'Milk', 'Cheese', 'Eggs')
# Food stuff (list): ['Apple', 'Banana', 'Mango', 'Carrot', 'Tomato', 'Spinach', 'Milk', 'Cheese', 'Eggs']
# Middle item(s): ['Tomato']
# First three items: ['Apple', 'Banana', 'Mango']
# Last three items: ['Milk', 'Cheese', 'Eggs']
# Is Estonia a nordic country? False
# Is Iceland a nordic country? True

# %% [markdown]
# ### set exercises

# %%
# Sets Exercises: Level 1

it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]

# Find the length of the set it_companies
print(f"Length of it_companies: {len(it_companies)}")

# Add 'Twitter' to it_companies
it_companies.add('Twitter')
print(f"it_companies after adding 'Twitter': {it_companies}")

# Insert multiple IT companies at once to the set it_companies
it_companies.update(['Snapchat', 'LinkedIn', 'TikTok'])
print(f"it_companies after adding multiple companies: {it_companies}")

# Remove one of the companies from the set it_companies
it_companies.remove('Snapchat')  # Raises an error if the item doesn't exist
print(f"it_companies after removing 'Snapchat': {it_companies}")

# Difference between remove and discard
# `remove` raises an error if the item doesn't exist, while `discard` does not.
it_companies.discard('NonExistentCompany')  # No error even if the item doesn't exist

# Sets Exercises: Level 2

# Join A and B
A_union_B = A.union(B)
print(f"A union B: {A_union_B}")

# Find A intersection B
A_intersection_B = A.intersection(B)
print(f"A intersection B: {A_intersection_B}")

# Is A subset of B
is_A_subset_B = A.issubset(B)
print(f"Is A subset of B? {is_A_subset_B}")

# Are A and B disjoint sets
are_A_B_disjoint = A.isdisjoint(B)
print(f"Are A and B disjoint? {are_A_B_disjoint}")

# Join A with B and B with A
A_join_B = A.union(B)
B_join_A = B.union(A)
print(f"A joined with B: {A_join_B}")
print(f"B joined with A: {B_join_A}")

# What is the symmetric difference between A and B
symmetric_diff = A.symmetric_difference(B)
print(f"Symmetric difference between A and B: {symmetric_diff}")

# Delete the sets completely
del A, B

# Sets Exercises: Level 3

# Convert the ages to a set and compare the length of the list and the set
age_set = set(age)
print(f"Length of age list: {len(age)}")
print(f"Length of age set: {len(age_set)}")
print("The list is bigger than the set." if len(age) > len(age_set) else "The set is bigger or equal.")

# Difference between string, list, tuple, and set
data_type_explanation = """
- String: Immutable sequence of characters, e.g., 'hello'.
- List: Mutable sequence of items, allows duplicates, e.g., [1, 2, 3].
- Tuple: Immutable sequence of items, allows duplicates, e.g., (1, 2, 3).
- Set: Unordered, mutable collection of unique items, e.g., {1, 2, 3}.
"""
print(data_type_explanation)

# Unique words in a sentence
sentence = "I am a teacher and I love to inspire and teach people."
unique_words = set(sentence.split())
print(f"Number of unique words: {len(unique_words)}")
print(f"Unique words: {unique_words}")
# Out:
# Length of it_companies: 7
# it_companies after adding 'Twitter': {'IBM', 'Microsoft', 'Facebook', 'Amazon', 'Google', 'Oracle', 'Twitter', 'Apple'}
# it_companies after adding multiple companies: {'Microsoft', 'LinkedIn', 'Facebook', 'Google', 'Amazon', 'Twitter', 'TikTok', 'Apple', 'IBM', 'Oracle', 'Snapchat'}
# it_companies after removing 'Snapchat': {'Microsoft', 'LinkedIn', 'Facebook', 'Google', 'Amazon', 'Twitter', 'TikTok', 'Apple', 'IBM', 'Oracle'}
# A union B: {19, 20, 22, 24, 25, 26, 27, 28}
# A intersection B: {19, 20, 22, 24, 25, 26}
# Is A subset of B? True
# Are A and B disjoint? False
# A joined with B: {19, 20, 22, 24, 25, 26, 27, 28}
# B joined with A: {19, 20, 22, 24, 25, 26, 27, 28}
# Symmetric difference between A and B: {27, 28}
# Length of age list: 8
# Length of age set: 5
# The list is bigger than the set.
#
# - String: Immutable sequence of characters, e.g., 'hello'.
# - List: Mutable sequence of items, allows duplicates, e.g., [1, 2, 3].
# ...
