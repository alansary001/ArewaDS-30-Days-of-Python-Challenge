# %% [markdown]
# ### Exercise 3

# %%
Age = 34
Height = 6.1
complex_num = 3 + 4j
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = 0.5 * base * height
print("The area of the triangle is: ", area)
## To check the perimeter of the triangle
side1 = float(input("Enter the first side of the triangle: "))
side2 = float(input("Enter the second side of the triangle: "))
side3 = float(input("Enter the third side of the triangle: "))
perimeter = side1 + side2 + side3
print("The perimeter of the triangle is: ", perimeter)
## to check the length and breadth of the rectangle
length = float(input("Enter the length of the rectangle: "))
breadth = float(input("Enter the breadth of the rectangle: "))
area = length * breadth
print("The area of the rectangle is: ", area)
perimeter = 2 * (length + breadth)
print("The perimeter of the rectangle is: ", perimeter)
## to check the radius of the circle
radius = float(input("Enter the radius of the circle: "))
area = 3.14 * radius * radius
print("The area of the circle is: ", area)
circumference = 2 * 3.14 * radius
print("The circumference of the circle is: ", circumference)
## to calculate the slope of the line
import math

# Task 8: Equation of the line y = 2x - 2
# Slope (m)
m = 2
print(f"Slope of the line: {m}")

# X-Intercept: When y = 0
x_intercept = -(-2) / 2  # Solve for x in y = mx + c
print(f"X-Intercept: ({x_intercept}, 0)")

# Y-Intercept: When x = 0
y_intercept = 2 * 0 - 2  # Solve for y in y = mx + c
print(f"Y-Intercept: (0, {y_intercept})")

# Task 9: Points (2, 2) and (6, 10)
x1, y1 = 2, 2
x2, y2 = 6, 10

# Slope (m)
slope_points = (y2 - y1) / (x2 - x1)
print(f"Slope between points (2, 2) and (6, 10): {slope_points}")

# Euclidean Distance
distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
print(f"Euclidean distance between points (2, 2) and (6, 10): {distance:.2f}")

# Task 10: Compare slopes
if m == slope_points:
    print("The slopes are equal.")
else:
    print("The slopes are not equal.")
    ## Task 11
    # Task 1: Calculate y = x^2 + 6x + 9 and find x where y = 0
def calculate_y(x):
    return x**2 + 6*x + 9

# Try different x values
for x in range(-10, 1):  # Testing x values from -10 to 0
    y = calculate_y(x)
    print(f"For x = {x}, y = {y}")
    if y == 0:
        print(f"y is 0 when x = {x}")

# Task 2: Length comparison between 'python' and 'dragon'
python_length = len("python")
dragon_length = len("dragon")
falsy_comparison = python_length != dragon_length
print(f"Length of 'python': {python_length}, Length of 'dragon': {dragon_length}")
print(f"Falsy comparison statement: {falsy_comparison}")

# Task 3: Check if 'on' is found in both 'python' and 'dragon'
on_in_python = 'on' in "python"
on_in_dragon = 'on' in "dragon"
print(f"Is 'on' found in both 'python' and 'dragon': {on_in_python and on_in_dragon}")

# Task 4: Check if 'jargon' is in the sentence
sentence = "I hope this course is not full of jargon."
contains_jargon = 'jargon' in sentence
print(f"Is 'jargon' in the sentence: {contains_jargon}")

# Task 5: Check if there is no 'on' in both 'dragon' and 'python'
no_on_in_both = not ('on' in "python" and 'on' in "dragon")
print(f"There is no 'on' in both 'dragon' and 'python': {no_on_in_both}")

## length of the text in string
text = "python"
length = len(text)  # Find length
length_as_float = float(length)  # Convert to float
length_as_string = str(length_as_float)  # Convert to string

print(f"Length: {length}, Float: {length_as_float}, String: {length_as_string}")

# Check if a number is even
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is even.")
else:
    print(f"{number} is not even.")

floor_div = 7 // 3
converted_value = int(2.7)

print(f"Is floor division equal to int(2.7)? {floor_div == converted_value}")

print(f"Is type of '10' equal to type of 10? {type('10') == type(10)}")

int_value = 9.8
print(f"Is int_value equal to 10? {int_value == 10}")

# Prompt user for hours and rate per hour
hours = float(input("Enter hours: "))
rate_per_hour = float(input("Enter rate per hour: "))

# Calculate pay
weekly_earning = hours * rate_per_hour
print(f"Your weekly earning is {weekly_earning}")

# Prompt user for number of years
years_lived = int(input("Enter number of years you have lived: "))

# Calculate seconds lived
seconds_per_year = 365 * 24 * 60 * 60
total_seconds = years_lived * seconds_per_year

print(f"You have lived for {total_seconds} seconds.")

# Print the table
print("Number | Square | Cube | Fourth Power")
for i in range(1, 6):
    print(f"{i:<6} | {i**1:<6} | {i**2:<6} | {i**3:<6} | {i**4:<6}")
# Out:
# The area of the triangle is:  100.0
# The perimeter of the triangle is:  12.0
# The area of the rectangle is:  20.0
# The perimeter of the rectangle is:  18.0
# The area of the circle is:  78.5
# The circumference of the circle is:  31.400000000000002
# Slope of the line: 2
# X-Intercept: (1.0, 0)
# Y-Intercept: (0, -2)
# Slope between points (2, 2) and (6, 10): 2.0
# Euclidean distance between points (2, 2) and (6, 10): 8.94
# The slopes are equal.
# For x = -10, y = 49
# For x = -9, y = 36
# For x = -8, y = 25
# For x = -7, y = 16
# For x = -6, y = 9
# For x = -5, y = 4
# For x = -4, y = 1
# For x = -3, y = 0
# y is 0 when x = -3
# For x = -2, y = 1
# For x = -1, y = 4
# For x = 0, y = 9
# Length of 'python': 6, Length of 'dragon': 6
# Falsy comparison statement: False
# Is 'on' found in both 'python' and 'dragon': True
# Is 'jargon' in the sentence: True
# There is no 'on' in both 'dragon' and 'python': False
# Length: 6, Float: 6.0, String: 6.0
# 4 is even.
# ...
